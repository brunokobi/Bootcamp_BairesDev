# %% [markdown]
# <a href="https://colab.research.google.com/github/brunokobi/Bootcamp_BairesDev/blob/main/Redu%C3%A7%C3%A3o_de_Dimensionalidade_em_Imagens__RN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🖼️ Desafio de Processamento de Imagens
#
# ## 📋 Descrição do Desafio
# Seguindo o exemplo do algoritmo de binarização apresentado em nossa última aula, implemente um programa em **Python** 🐍 que realize as seguintes transformações em uma imagem colorida:
#
# 1. **Converter a imagem para níveis de cinza** (valores de 0 a 255).
# 2. **Converter a imagem para binária** (preto e branco, com valores de 0 e 255).
#
# ## 🎯 Objetivo
# A partir da imagem de entrada (colorida), obtenha duas saídas:
# - A imagem em níveis de cinza.
# - A imagem binarizada.
#
# ---
#
# 🚀 **Boa sorte no desafio e mãos à obra!**

# %%
# Importa as bibliotecas necessárias
import cv2
import matplotlib.pyplot as plt
from skimage import data
import numpy as np
import time

# Carrega a imagem colorida utilizando o skimage
default_image = data.astronaut()  # Astronaut é uma imagem colorida disponível no skimage

# Medir o tempo de processamento para a imagem original colorida
start_time = time.time()
# Simulação do processamento para a imagem original
color_process_time = time.time() - start_time

# Converte a imagem colorida para tons de cinza e mede o tempo
start_time = time.time()
gray_image = cv2.cvtColor(default_image, cv2.COLOR_RGB2GRAY)
gray_process_time = time.time() - start_time

# Converte a imagem em tons de cinza para binária e mede o tempo
start_time = time.time()
_, binary_image = cv2.threshold(gray_image, 128, 255, cv2.THRESH_BINARY)
binary_process_time = time.time() - start_time

# Plota as imagens original, em tons de cinza e binária
plt.figure(figsize=(12, 8))

# Plota a imagem colorida
plt.subplot(2, 3, 1)
plt.imshow(default_image)  # A imagem já está em RGB
plt.axis('off')
plt.title("Imagem Colorida")

# Plota a imagem em tons de cinza
plt.subplot(2, 3, 2)
plt.imshow(gray_image, cmap='gray')
plt.axis('off')
plt.title("Imagem em Tons de Cinza")

# Plota a imagem binária
plt.subplot(2, 3, 3)
plt.imshow(binary_image, cmap='gray')
plt.axis('off')
plt.title("Imagem Binária")

# Exibe o gráfico
plt.tight_layout()
plt.show()
